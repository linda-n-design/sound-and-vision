# %%
import pandas as pd
df = pd.read_excel('music.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_excel('music.xlsx')
#       3 df.head()
#
# File ~/sound-and-vision-env/lib/python3.14/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File ~/sound-and-vision-env/lib/python3.14/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File ~/sound-and-vision-env/lib/python3.14/site-packages/pandas/io/excel/_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File ~/sound-and-vision-env/lib/python3.14/site-packages/pandas/io/common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'music.xlsx'

# %%
import os
print(os.getcwd())
# Out:
# /Users/lindanakasone/Documents/GitHub/sound-and-vision/notebooks

# %%
import pandas as pd
df = pd.read_excel('../data/music.xlsx')
df.head()
# Out:
#                              Song  Duration Featured Artist Collaborators  \
# 0   Living a Boy's Adventure Tale  05:03:00            a-ha           NaN
# 1            I Dream Myself Alive  03:10:00            a-ha           NaN
# 2  Here I Stand And Face The Rain  04:33:00            a-ha           NaN
# 3            I've Been Losing You  04:26:00            a-ha           NaN
# 4            The Living Daylights  04:14:00            a-ha           NaN
#
#                    Album  Year Artist Location Primary Language     Genre  \
# 0     Hunting High & Low  1985          Norway          English  New Wave
# 1     Hunting High & Low  1985          Norway          English  New Wave
# 2     Hunting High & Low  1985          Norway          English  New Wave
# 3  The Singles 1984-2004  1986          Norway          English  New Wave
# 4  The Singles 1984-2004  1987          Norway          English  New Wave
#
#   Genre_Apple  Tempo Vocal Arrangement Lead Instrument  Mood  Subject Matter  \
# 0         Pop    NaN               NaN             NaN   NaN             NaN
# 1         Pop    NaN               NaN             NaN   NaN             NaN
# 2         Pop    NaN               NaN             NaN   NaN             NaN
# 3         Pop    NaN               NaN             NaN   NaN             NaN
# 4         Pop    NaN               NaN             NaN   NaN             NaN
#
#   Cover  Chorus
# 0   NaN     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN
# 4   NaN     NaN

# %%
df.to_json('../data/songs.json', orient='records', indent=2)
